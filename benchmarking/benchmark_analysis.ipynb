# %%
import pandas as pd 
from pathlib import Path

# %%
ROOT = Path("..")
BENCHMARK_RESULTS_DIR = ROOT / "data" / "Benchmark" / "results"
df = pd.read_csv(BENCHMARK_RESULTS_DIR / "rec_soap-fullanswer-tf-fr.csv", sep=",")

# %%
df
# Out:
#                                               content  label
# 0   AYAAAAAAAAAAAA LES CRACKHEAD ANTI MIGRANT BORD...      1
# 1   Bordel le gars chantait 'FN souffrance' alors ...      0
# 2   Je vois que ça ddb en masse\nComme en dictatur...      1
# 3   vous tenez là ? persoent c'est chaud depuis hi...      1
# 4   Le racisme est devenu le crime ultime en Occid...      0
# ..                                                ...    ...
# 59  Demain sera le jour d'après. Qui nous protège ...      1
# 60                                On parle de quoi là      0
# 61  il est totalement obèse\non va partir du princ...      1
# 62  C'est la période de reproduction des KJ , ils ...      0
# 63                 premier zoophile non assumé\n:oui:      0
#
# [64 rows x 2 columns]

# %%
df['label'].value_counts()
# Out:
# label
# 0    40
# 1    24
# Name: count, dtype: int64
